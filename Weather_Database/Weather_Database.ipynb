# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

# Create the counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
        
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather ["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | gatton
# Processing Record 2 of Set 1 | tevaitoa
# Processing Record 3 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | urumqi
# Processing Record 8 of Set 1 | yellowknife
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | esperance
# Processing Record 11 of Set 1 | teguldet
# Processing Record 12 of Set 1 | katsuura
# Processing Record 13 of Set 1 | ponta do sol
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | albanel
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | ban mo
# Processing Record 19 of Set 1 | hualmay
# Processing Record 20 of Set 1 | sitka
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | mayumba
# Processing Record 23 of Set 1 | beauchamps
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | lagoa
# Processing Record 26 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 1 | morondava
# Processing Record 28 of Set 1 | chara
# Processing Record 29 of Set 1 | kaitangata
# Processing Record 30 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | smithers
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 1 | yarkovo
# Processing Record 37 of Set 1 | wucheng
# Processing Record 38 of Set 1 | paragominas
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | wewak
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | busselton
# Processing Record 46 of Set 1 | zaraza
# Processing Record 47 of Set 1 | kabinda
# Processing Record 48 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 1 | naberera
# Processing Record 50 of Set 1 | mtambile
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | pavilosta
# Processing Record 3 of Set 2 | bandarbeyla
# Processing Record 4 of Set 2 | port-gentil
# Processing Record 5 of Set 2 | san patricio
# Processing Record 6 of Set 2 | hambantota
# Processing Record 7 of Set 2 | rapid valley
# Processing Record 8 of Set 2 | nebolchi
# Processing Record 9 of Set 2 | sandviken
# Processing Record 10 of Set 2 | mantua
# Processing Record 11 of Set 2 | sibolga
# Processing Record 12 of Set 2 | rawlins
# Processing Record 13 of Set 2 | okakarara
# Processing Record 14 of Set 2 | taloqan
# Processing Record 15 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | saldanha
# Processing Record 21 of Set 2 | mana
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | kirakira
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | robertsport
# Processing Record 28 of Set 2 | bac lieu
# Processing Record 29 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 2 | mapastepec
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | ulagan
# Processing Record 33 of Set 2 | ancud
# Processing Record 34 of Set 2 | kargasok
# Processing Record 35 of Set 2 | bongandanga
# Processing Record 36 of Set 2 | qaqortoq
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | tuatapere
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | santo domingo
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | longyearbyen
# Processing Record 43 of Set 2 | fairbanks
# Processing Record 44 of Set 2 | sukhumi
# Processing Record 45 of Set 2 | celestun
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | bonoua
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | lavrentiya
# Processing Record 1 of Set 3 | campo maior
# Processing Record 2 of Set 3 | olafsvik
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | trinidad
# Processing Record 5 of Set 3 | hilo
# Processing Record 6 of Set 3 | iqaluit
# Processing Record 7 of Set 3 | coquimbo
# Processing Record 8 of Set 3 | ambilobe
# Processing Record 9 of Set 3 | alta floresta
# Processing Record 10 of Set 3 | balikpapan
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | kushima
# Processing Record 13 of Set 3 | voh
# Processing Record 14 of Set 3 | linqiong
# Processing Record 15 of Set 3 | bracebridge
# Processing Record 16 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 3 | ahipara
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | culebra
# Processing Record 21 of Set 3 | podor
# Processing Record 22 of Set 3 | new norfolk
# Processing Record 23 of Set 3 | rocha
# Processing Record 24 of Set 3 | namibe
# Processing Record 25 of Set 3 | bilibino
# Processing Record 26 of Set 3 | grindavik
# Processing Record 27 of Set 3 | moose factory
# Processing Record 28 of Set 3 | korla
# Processing Record 29 of Set 3 | akdepe
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | talnakh
# Processing Record 32 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | san quintin
# Processing Record 35 of Set 3 | nuuk
# Processing Record 36 of Set 3 | odesskoye
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | anadyr
# Processing Record 40 of Set 3 | saint-francois
# Processing Record 41 of Set 3 | mount isa
# Processing Record 42 of Set 3 | bayji
# Processing Record 43 of Set 3 | saint george
# Processing Record 44 of Set 3 | kapaa
# Processing Record 45 of Set 3 | veraval
# Processing Record 46 of Set 3 | griffith
# Processing Record 47 of Set 3 | kavieng
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | ostrovnoy
# Processing Record 50 of Set 3 | santa ines
# Processing Record 1 of Set 4 | bilma
# Processing Record 2 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 4 | vila
# Processing Record 4 of Set 4 | phan thiet
# Processing Record 5 of Set 4 | tuktoyaktuk
# Processing Record 6 of Set 4 | dolores
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 9 of Set 4 | beloha
# Processing Record 10 of Set 4 | holoby
# Processing Record 11 of Set 4 | mataura
# Processing Record 12 of Set 4 | ceres
# Processing Record 13 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 4 | buraydah
# Processing Record 15 of Set 4 | jining
# Processing Record 16 of Set 4 | kulhudhuffushi
# Processing Record 17 of Set 4 | tigil
# Processing Record 18 of Set 4 | kharp
# Processing Record 19 of Set 4 | arraial do cabo
# Processing Record 20 of Set 4 | west wendover
# Processing Record 21 of Set 4 | pochutla
# Processing Record 22 of Set 4 | cozumel
# Processing Record 23 of Set 4 | hithadhoo
# Processing Record 24 of Set 4 | nanortalik
# Processing Record 25 of Set 4 | mangai
# Processing Record 26 of Set 4 | provideniya
# Processing Record 27 of Set 4 | shouguang
# Processing Record 28 of Set 4 | tenali
# Processing Record 29 of Set 4 | caravelas
# Processing Record 30 of Set 4 | kendrapara
# Processing Record 31 of Set 4 | samarai
# Processing Record 32 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 4 | tarogong
# Processing Record 34 of Set 4 | lamu
# Processing Record 35 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 4 | isiro
# Processing Record 37 of Set 4 | erzin
# Processing Record 38 of Set 4 | carnarvon
# Processing Record 39 of Set 4 | xiaoweizhai
# Processing Record 40 of Set 4 | sento se
# City not found. Skipping...
# Processing Record 41 of Set 4 | thompson
# Processing Record 42 of Set 4 | edd
# Processing Record 43 of Set 4 | awbari
# Processing Record 44 of Set 4 | kupang
# Processing Record 45 of Set 4 | filingue
# Processing Record 46 of Set 4 | japura
# Processing Record 47 of Set 4 | darab
# Processing Record 48 of Set 4 | aklavik
# Processing Record 49 of Set 4 | verkhovazhye
# Processing Record 50 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 2 of Set 5 | cercal
# Processing Record 3 of Set 5 | mehamn
# Processing Record 4 of Set 5 | akyab
# Processing Record 5 of Set 5 | haines junction
# Processing Record 6 of Set 5 | kjollefjord
# Processing Record 7 of Set 5 | faanui
# Processing Record 8 of Set 5 | atasu
# Processing Record 9 of Set 5 | belmonte
# Processing Record 10 of Set 5 | vanavara
# Processing Record 11 of Set 5 | vao
# Processing Record 12 of Set 5 | leningradskiy
# Processing Record 13 of Set 5 | bonthe
# Processing Record 14 of Set 5 | verkhoyansk
# Processing Record 15 of Set 5 | cherskiy
# Processing Record 16 of Set 5 | cholan
# City not found. Skipping...
# Processing Record 17 of Set 5 | banda aceh
# Processing Record 18 of Set 5 | ixtapa
# Processing Record 19 of Set 5 | kavaratti
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | islampur
# Processing Record 22 of Set 5 | saint-philippe
# Processing Record 23 of Set 5 | grand gaube
# Processing Record 24 of Set 5 | srednekolymsk
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | coahuayana
# Processing Record 27 of Set 5 | puksoozero
# Processing Record 28 of Set 5 | chimbote
# Processing Record 29 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 30 of Set 5 | stornoway
# Processing Record 31 of Set 5 | kamenka
# Processing Record 32 of Set 5 | rusape
# Processing Record 33 of Set 5 | ngaoundere
# Processing Record 34 of Set 5 | portland
# Processing Record 35 of Set 5 | cornelio procopio
# Processing Record 36 of Set 5 | kloulklubed
# Processing Record 37 of Set 5 | raudeberg
# Processing Record 38 of Set 5 | boyolangu
# Processing Record 39 of Set 5 | pevek
# Processing Record 40 of Set 5 | sukumo
# Processing Record 41 of Set 5 | fort nelson
# Processing Record 42 of Set 5 | kodiak
# Processing Record 43 of Set 5 | high level
# Processing Record 44 of Set 5 | el sauce
# Processing Record 45 of Set 5 | lazaro cardenas
# Processing Record 46 of Set 5 | castro
# Processing Record 47 of Set 5 | gamboula
# Processing Record 48 of Set 5 | luorong
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | nelson bay
# Processing Record 1 of Set 6 | shiyan
# Processing Record 2 of Set 6 | victor harbor
# Processing Record 3 of Set 6 | yumen
# Processing Record 4 of Set 6 | mayo
# Processing Record 5 of Set 6 | talara
# Processing Record 6 of Set 6 | mwene-ditu
# Processing Record 7 of Set 6 | atar
# Processing Record 8 of Set 6 | aksu
# Processing Record 9 of Set 6 | pervomayskoye
# Processing Record 10 of Set 6 | terney
# Processing Record 11 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 6 | benguela
# Processing Record 13 of Set 6 | bahia blanca
# Processing Record 14 of Set 6 | bathsheba
# Processing Record 15 of Set 6 | krasnoselkup
# Processing Record 16 of Set 6 | cabo san lucas
# Processing Record 17 of Set 6 | sur
# Processing Record 18 of Set 6 | ormara
# Processing Record 19 of Set 6 | zakopane
# Processing Record 20 of Set 6 | lewiston
# Processing Record 21 of Set 6 | pangody
# Processing Record 22 of Set 6 | kiruna
# Processing Record 23 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 6 | geraldton
# Processing Record 25 of Set 6 | manta
# Processing Record 26 of Set 6 | astoria
# Processing Record 27 of Set 6 | ippy
# Processing Record 28 of Set 6 | naze
# Processing Record 29 of Set 6 | gat
# Processing Record 30 of Set 6 | abu samrah
# Processing Record 31 of Set 6 | ferrol
# Processing Record 32 of Set 6 | anse-bertrand
# Processing Record 33 of Set 6 | avera
# Processing Record 34 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 6 | maceio
# Processing Record 36 of Set 6 | nhulunbuy
# Processing Record 37 of Set 6 | uruzgan
# Processing Record 38 of Set 6 | nantucket
# Processing Record 39 of Set 6 | bethel
# Processing Record 40 of Set 6 | lompoc
# Processing Record 41 of Set 6 | mercedes
# Processing Record 42 of Set 6 | dikson
# Processing Record 43 of Set 6 | port hardy
# Processing Record 44 of Set 6 | alice springs
# Processing Record 45 of Set 6 | fare
# Processing Record 46 of Set 6 | esso
# Processing Record 47 of Set 6 | qaanaaq
# Processing Record 48 of Set 6 | gondanglegi
# Processing Record 49 of Set 6 | tessalit
# Processing Record 50 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 1 of Set 7 | loa janan
# Processing Record 2 of Set 7 | taiyuan
# Processing Record 3 of Set 7 | doha
# Processing Record 4 of Set 7 | vryburg
# Processing Record 5 of Set 7 | port maria
# Processing Record 6 of Set 7 | santa maria da vitoria
# Processing Record 7 of Set 7 | bossangoa
# Processing Record 8 of Set 7 | puente grande
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | port hueneme
# Processing Record 11 of Set 7 | cabo rojo
# Processing Record 12 of Set 7 | hagen
# Processing Record 13 of Set 7 | estelle
# Processing Record 14 of Set 7 | nilagiri
# Processing Record 15 of Set 7 | isangel
# Processing Record 16 of Set 7 | lahij
# Processing Record 17 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 18 of Set 7 | dhankuta
# Processing Record 19 of Set 7 | touros
# Processing Record 20 of Set 7 | gornopravdinsk
# Processing Record 21 of Set 7 | taoudenni
# Processing Record 22 of Set 7 | muli
# Processing Record 23 of Set 7 | sicamous
# Processing Record 24 of Set 7 | praia da vitoria
# Processing Record 25 of Set 7 | seoul
# Processing Record 26 of Set 7 | iwata
# Processing Record 27 of Set 7 | waddan
# Processing Record 28 of Set 7 | nouadhibou
# Processing Record 29 of Set 7 | sovetskaya gavan
# Processing Record 30 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 7 | yokadouma
# Processing Record 32 of Set 7 | dingle
# Processing Record 33 of Set 7 | kiunga
# Processing Record 34 of Set 7 | bani walid
# Processing Record 35 of Set 7 | buckeye
# Processing Record 36 of Set 7 | qasigiannguit
# Processing Record 37 of Set 7 | vila velha
# Processing Record 38 of Set 7 | domoni
# Processing Record 39 of Set 7 | saint-georges
# Processing Record 40 of Set 7 | gamba
# Processing Record 41 of Set 7 | aykhal
# Processing Record 42 of Set 7 | dunedin
# Processing Record 43 of Set 7 | marsa matruh
# Processing Record 44 of Set 7 | masunga
# Processing Record 45 of Set 7 | dakoro
# Processing Record 46 of Set 7 | klaksvik
# Processing Record 47 of Set 7 | richards bay
# Processing Record 48 of Set 7 | qui nhon
# Processing Record 49 of Set 7 | sulya
# Processing Record 50 of Set 7 | saint-pierre
# Processing Record 1 of Set 8 | san francisco
# Processing Record 2 of Set 8 | ozinki
# Processing Record 3 of Set 8 | dudinka
# Processing Record 4 of Set 8 | severo-kurilsk
# Processing Record 5 of Set 8 | zhob
# Processing Record 6 of Set 8 | paamiut
# Processing Record 7 of Set 8 | daitari
# Processing Record 8 of Set 8 | golovchino
# Processing Record 9 of Set 8 | reconquista
# Processing Record 10 of Set 8 | mirnyy
# Processing Record 11 of Set 8 | yulara
# Processing Record 12 of Set 8 | college
# Processing Record 13 of Set 8 | poronaysk
# Processing Record 14 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 8 | pacific grove
# Processing Record 16 of Set 8 | metro
# Processing Record 17 of Set 8 | brandenburg
# Processing Record 18 of Set 8 | tunkas
# Processing Record 19 of Set 8 | yilan
# Processing Record 20 of Set 8 | harper
# Processing Record 21 of Set 8 | constitucion
# Processing Record 22 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 8 | evensk
# Processing Record 24 of Set 8 | yar-sale
# Processing Record 25 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 8 | bekhtery
# Processing Record 27 of Set 8 | belyy yar
# Processing Record 28 of Set 8 | behbahan
# Processing Record 29 of Set 8 | swan river
# Processing Record 30 of Set 8 | bayburt
# Processing Record 31 of Set 8 | lebowakgomo
# Processing Record 32 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 8 | hofn
# Processing Record 34 of Set 8 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 35 of Set 8 | vagur
# Processing Record 36 of Set 8 | bintulu
# Processing Record 37 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 8 | novikovo
# Processing Record 39 of Set 8 | torbay
# Processing Record 40 of Set 8 | gidam
# Processing Record 41 of Set 8 | gurgan
# City not found. Skipping...
# Processing Record 42 of Set 8 | camana
# Processing Record 43 of Set 8 | manaure
# Processing Record 44 of Set 8 | jalu
# Processing Record 45 of Set 8 | merauke
# Processing Record 46 of Set 8 | marawi
# Processing Record 47 of Set 8 | pudozh
# Processing Record 48 of Set 8 | half moon bay
# Processing Record 49 of Set 8 | bundaberg
# Processing Record 50 of Set 8 | kandrian
# Processing Record 1 of Set 9 | adrar
# Processing Record 2 of Set 9 | salisbury
# Processing Record 3 of Set 9 | kigorobya
# Processing Record 4 of Set 9 | nizhneudinsk
# Processing Record 5 of Set 9 | belz
# Processing Record 6 of Set 9 | assela
# City not found. Skipping...
# Processing Record 7 of Set 9 | nome
# Processing Record 8 of Set 9 | comodoro rivadavia
# Processing Record 9 of Set 9 | gore
# Processing Record 10 of Set 9 | sawakin
# Processing Record 11 of Set 9 | chegdomyn
# Processing Record 12 of Set 9 | olavarria
# Processing Record 13 of Set 9 | hasaki
# Processing Record 14 of Set 9 | tabou
# Processing Record 15 of Set 9 | stuttgart
# Processing Record 16 of Set 9 | fryanovo
# Processing Record 17 of Set 9 | guiratinga
# Processing Record 18 of Set 9 | lamtah
# Processing Record 19 of Set 9 | iskateley
# Processing Record 20 of Set 9 | vila franca do campo
# Processing Record 21 of Set 9 | warrington
# Processing Record 22 of Set 9 | komsomolskiy
# Processing Record 23 of Set 9 | latung
# Processing Record 24 of Set 9 | bonga
# Processing Record 25 of Set 9 | sao miguel do araguaia
# Processing Record 26 of Set 9 | sandpoint
# Processing Record 27 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 9 | pavino
# Processing Record 29 of Set 9 | oneonta
# Processing Record 30 of Set 9 | luwuk
# Processing Record 31 of Set 9 | pringsewu
# Processing Record 32 of Set 9 | hamilton
# Processing Record 33 of Set 9 | havelock
# Processing Record 34 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 9 | pangnirtung
# Processing Record 36 of Set 9 | narsaq
# Processing Record 37 of Set 9 | rio grande
# Processing Record 38 of Set 9 | tashtyp
# Processing Record 39 of Set 9 | asau
# Processing Record 40 of Set 9 | pestravka
# Processing Record 41 of Set 9 | hurghada
# Processing Record 42 of Set 9 | zhaozhou
# Processing Record 43 of Set 9 | eyl
# Processing Record 44 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 9 | lielvarde
# Processing Record 46 of Set 9 | boende
# Processing Record 47 of Set 9 | feijo
# Processing Record 48 of Set 9 | san policarpo
# Processing Record 49 of Set 9 | morant bay
# Processing Record 50 of Set 9 | port hedland
# Processing Record 1 of Set 10 | green river
# Processing Record 2 of Set 10 | khani
# Processing Record 3 of Set 10 | bowen
# Processing Record 4 of Set 10 | wellington
# Processing Record 5 of Set 10 | le port
# Processing Record 6 of Set 10 | aripuana
# Processing Record 7 of Set 10 | constantine
# Processing Record 8 of Set 10 | mackay
# Processing Record 9 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 10 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 10 | wamba
# Processing Record 12 of Set 10 | makinsk
# Processing Record 13 of Set 10 | san andres
# Processing Record 14 of Set 10 | shache
# Processing Record 15 of Set 10 | lichuan
# Processing Record 16 of Set 10 | sobolevo
# Processing Record 17 of Set 10 | shetpe
# Processing Record 18 of Set 10 | mitchell
# Processing Record 19 of Set 10 | nauta
# Processing Record 20 of Set 10 | kutum
# Processing Record 21 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 22 of Set 10 | trat
# Processing Record 23 of Set 10 | jacareacanga
# Processing Record 24 of Set 10 | nanning
# Processing Record 25 of Set 10 | cidreira
# Processing Record 26 of Set 10 | tual
# Processing Record 27 of Set 10 | road town
# Processing Record 28 of Set 10 | santo antonio do ica
# Processing Record 29 of Set 10 | kapit
# Processing Record 30 of Set 10 | bonnyville
# Processing Record 31 of Set 10 | baghdad
# Processing Record 32 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 10 | rio de janeiro
# Processing Record 34 of Set 10 | shelburne
# Processing Record 35 of Set 10 | daru
# Processing Record 36 of Set 10 | mandla
# Processing Record 37 of Set 10 | corbelia
# Processing Record 38 of Set 10 | gushikawa
# Processing Record 39 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 10 | fortuna
# Processing Record 41 of Set 10 | aliartos
# Processing Record 42 of Set 10 | havre-saint-pierre
# Processing Record 43 of Set 10 | satun
# Processing Record 44 of Set 10 | karratha
# Processing Record 45 of Set 10 | synya
# Processing Record 46 of Set 10 | lalomanu
# City not found. Skipping...
# Processing Record 47 of Set 10 | clacton-on-sea
# Processing Record 48 of Set 10 | hohhot
# Processing Record 49 of Set 10 | vasylivka
# Processing Record 50 of Set 10 | las palmas
# Processing Record 1 of Set 11 | aqtobe
# Processing Record 2 of Set 11 | baruun-urt
# Processing Record 3 of Set 11 | kenai
# Processing Record 4 of Set 11 | natal
# Processing Record 5 of Set 11 | nizhnevartovsk
# Processing Record 6 of Set 11 | barcelos
# Processing Record 7 of Set 11 | ndele
# Processing Record 8 of Set 11 | pundaguitan
# Processing Record 9 of Set 11 | sangar
# Processing Record 10 of Set 11 | lagos
# Processing Record 11 of Set 11 | strezhevoy
# Processing Record 12 of Set 11 | hami
# Processing Record 13 of Set 11 | posse
# Processing Record 14 of Set 11 | kendari
# Processing Record 15 of Set 11 | ulaanbaatar
# Processing Record 16 of Set 11 | kuremaa
# Processing Record 17 of Set 11 | malakal
# Processing Record 18 of Set 11 | lorengau
# Processing Record 19 of Set 11 | camacha
# Processing Record 20 of Set 11 | shahganj
# Processing Record 21 of Set 11 | namatanai
# Processing Record 22 of Set 11 | swan hill
# Processing Record 23 of Set 11 | ballina
# Processing Record 24 of Set 11 | atambua
# Processing Record 25 of Set 11 | hovd
# Processing Record 26 of Set 11 | katobu
# Processing Record 27 of Set 11 | meulaboh
# Processing Record 28 of Set 11 | noumea
# Processing Record 29 of Set 11 | gazanjyk
# Processing Record 30 of Set 11 | novyy urengoy
# Processing Record 31 of Set 11 | ilulissat
# Processing Record 32 of Set 11 | new bern
# Processing Record 33 of Set 11 | ketchikan
# Processing Record 34 of Set 11 | mitsuke
# Processing Record 35 of Set 11 | krasnovishersk
# Processing Record 36 of Set 11 | bambous virieux
# Processing Record 37 of Set 11 | port hawkesbury
# Processing Record 38 of Set 11 | amahai
# Processing Record 39 of Set 11 | sao filipe
# Processing Record 40 of Set 11 | tiznit
# Processing Record 41 of Set 11 | marsh harbour
# Processing Record 42 of Set 11 | neryungri
# Processing Record 43 of Set 11 | jiuquan
# Processing Record 44 of Set 11 | bell ville
# Processing Record 45 of Set 11 | ontario
# Processing Record 46 of Set 11 | savino
# Processing Record 47 of Set 11 | varca
# Processing Record 48 of Set 11 | bull savanna
# Processing Record 49 of Set 11 | makakilo city
# Processing Record 50 of Set 11 | kieta
# Processing Record 1 of Set 12 | roebourne
# Processing Record 2 of Set 12 | aligudarz
# Processing Record 3 of Set 12 | vidim
# Processing Record 4 of Set 12 | codrington
# Processing Record 5 of Set 12 | san carlos de bariloche
# Processing Record 6 of Set 12 | kyabe
# Processing Record 7 of Set 12 | bismarck
# Processing Record 8 of Set 12 | presidente epitacio
# Processing Record 9 of Set 12 | liuhe
# Processing Record 10 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 12 | tanout
# Processing Record 12 of Set 12 | el alto
# Processing Record 13 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 12 | bani
# Processing Record 15 of Set 12 | rawson
# Processing Record 16 of Set 12 | kismayo
# Processing Record 17 of Set 12 | yerbogachen
# Processing Record 18 of Set 12 | aranos
# Processing Record 19 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 12 | bitkine
# Processing Record 21 of Set 12 | artyom
# Processing Record 22 of Set 12 | lujan
# Processing Record 23 of Set 12 | sipe sipe
# Processing Record 24 of Set 12 | tura
# Processing Record 25 of Set 12 | kristinehamn
# Processing Record 26 of Set 12 | lasa
# Processing Record 27 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 12 | whitehorse
# Processing Record 29 of Set 12 | okhotsk
# Processing Record 30 of Set 12 | peachland
# Processing Record 31 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 12 | christchurch
# Processing Record 33 of Set 12 | bairiki
# Processing Record 34 of Set 12 | oxapampa
# Processing Record 35 of Set 12 | udachnyy
# Processing Record 36 of Set 12 | puerto del rosario
# Processing Record 37 of Set 12 | riyadh
# Processing Record 38 of Set 12 | salalah
# Processing Record 39 of Set 12 | kawalu
# Processing Record 40 of Set 12 | eregli
# Processing Record 41 of Set 12 | cabedelo
# Processing Record 42 of Set 12 | alpena
# Processing Record 43 of Set 12 | penzance
# Processing Record 44 of Set 12 | khandyga
# Processing Record 45 of Set 12 | nalut
# Processing Record 46 of Set 12 | pimentel
# Processing Record 47 of Set 12 | teguise
# Processing Record 48 of Set 12 | krutikha
# Processing Record 49 of Set 12 | dwarka
# Processing Record 50 of Set 12 | brae
# Processing Record 1 of Set 13 | arlit
# Processing Record 2 of Set 13 | calbuco
# Processing Record 3 of Set 13 | coihaique
# Processing Record 4 of Set 13 | tromso
# Processing Record 5 of Set 13 | severnoye
# Processing Record 6 of Set 13 | mende
# Processing Record 7 of Set 13 | tazmalt
# Processing Record 8 of Set 13 | davila
# Processing Record 9 of Set 13 | oranjestad
# Processing Record 10 of Set 13 | turukhansk
# Processing Record 11 of Set 13 | sompeta
# Processing Record 12 of Set 13 | guerrero negro
# Processing Record 13 of Set 13 | novo aripuana
# Processing Record 14 of Set 13 | mastic beach
# Processing Record 15 of Set 13 | oriximina
# Processing Record 16 of Set 13 | margherita
# Processing Record 17 of Set 13 | eureka
# Processing Record 18 of Set 13 | pousat
# City not found. Skipping...
# Processing Record 19 of Set 13 | el carmen
# Processing Record 20 of Set 13 | hokitika
# Processing Record 21 of Set 13 | elliot
# Processing Record 22 of Set 13 | buta
# Processing Record 23 of Set 13 | temir
# Processing Record 24 of Set 13 | beyneu
# Processing Record 25 of Set 13 | bogalusa
# Processing Record 26 of Set 13 | cayenne
# Processing Record 27 of Set 13 | ilabaya
# Processing Record 28 of Set 13 | beitbridge
# Processing Record 29 of Set 13 | jacqueville
# Processing Record 30 of Set 13 | roma
# Processing Record 31 of Set 13 | nawa
# Processing Record 32 of Set 13 | vardo
# Processing Record 33 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 13 | sao geraldo do araguaia
# Processing Record 35 of Set 13 | henties bay
# Processing Record 36 of Set 13 | tautira
# Processing Record 37 of Set 13 | udimskiy
# Processing Record 38 of Set 13 | safaga
# Processing Record 39 of Set 13 | sfantu gheorghe
# Processing Record 40 of Set 13 | champerico
# Processing Record 41 of Set 13 | okha
# Processing Record 42 of Set 13 | saint-augustin
# Processing Record 43 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 13 | odienne
# Processing Record 45 of Set 13 | sinnamary
# Processing Record 46 of Set 13 | waingapu
# Processing Record 47 of Set 13 | palmerston
# Processing Record 48 of Set 13 | saurimo
# Processing Record 49 of Set 13 | sarakhs
# Processing Record 50 of Set 13 | ulladulla
# Processing Record 1 of Set 14 | lubbenau
# Processing Record 2 of Set 14 | ulaangom
# Processing Record 3 of Set 14 | pisco
# Processing Record 4 of Set 14 | honiara
# Processing Record 5 of Set 14 | tucuman
# Processing Record 6 of Set 14 | sabang
# Processing Record 7 of Set 14 | chaohu
# Processing Record 8 of Set 14 | manggar
# Processing Record 9 of Set 14 | morgantown
# Processing Record 10 of Set 14 | suoyarvi
# Processing Record 11 of Set 14 | sohag
# Processing Record 12 of Set 14 | ngunguru
# Processing Record 13 of Set 14 | male
# Processing Record 14 of Set 14 | orange
# Processing Record 15 of Set 14 | presidencia roque saenz pena
# Processing Record 16 of Set 14 | taos
# Processing Record 17 of Set 14 | saint pete beach
# Processing Record 18 of Set 14 | jega
# Processing Record 19 of Set 14 | puerto narino
# Processing Record 20 of Set 14 | santa lucia
# Processing Record 21 of Set 14 | tunceli
# Processing Record 22 of Set 14 | sao joao da barra
# Processing Record 23 of Set 14 | loikaw
# Processing Record 24 of Set 14 | ranong
# Processing Record 25 of Set 14 | lima
# Processing Record 26 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 27 of Set 14 | mkushi
# Processing Record 28 of Set 14 | ghazipur
# Processing Record 29 of Set 14 | ust-nera
# Processing Record 30 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 31 of Set 14 | opuwo
# Processing Record 32 of Set 14 | magomeni
# Processing Record 33 of Set 14 | popondetta
# Processing Record 34 of Set 14 | sivaki
# Processing Record 35 of Set 14 | sovetskiy
# Processing Record 36 of Set 14 | ust-kuyga
# Processing Record 37 of Set 14 | zhanaozen
# Processing Record 38 of Set 14 | luanda
# Processing Record 39 of Set 14 | shingu
# Processing Record 40 of Set 14 | chirala
# Processing Record 41 of Set 14 | ashland
# Processing Record 42 of Set 14 | zaysan
# Processing Record 43 of Set 14 | adjumani
# Processing Record 44 of Set 14 | paslek
# Processing Record 45 of Set 14 | the valley
# Processing Record 46 of Set 14 | bousse
# Processing Record 47 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 48 of Set 14 | baicheng
# Processing Record 49 of Set 14 | tayu
# Processing Record 50 of Set 14 | seymchan
# Processing Record 1 of Set 15 | marmaron
# City not found. Skipping...
# Processing Record 2 of Set 15 | olga
# Processing Record 3 of Set 15 | nemuro
# Processing Record 4 of Set 15 | donegal
# Processing Record 5 of Set 15 | lewistown
# Processing Record 6 of Set 15 | pandan
# Processing Record 7 of Set 15 | vostok
# Processing Record 8 of Set 15 | bud
# Processing Record 9 of Set 15 | buturlino
# Processing Record 10 of Set 15 | jackson
# Processing Record 11 of Set 15 | fort thomas
# Processing Record 12 of Set 15 | marathon
# Processing Record 13 of Set 15 | saint anthony
# Processing Record 14 of Set 15 | talcahuano
# Processing Record 15 of Set 15 | inirida
# Processing Record 16 of Set 15 | lubango
# Processing Record 17 of Set 15 | batagay
# Processing Record 18 of Set 15 | jiaonan
# Processing Record 19 of Set 15 | kabala
# Processing Record 20 of Set 15 | watford
# Processing Record 21 of Set 15 | nishihara
# Processing Record 22 of Set 15 | pandan niog
# Processing Record 23 of Set 15 | port shepstone
# Processing Record 24 of Set 15 | sortland
# Processing Record 25 of Set 15 | san cristobal
# Processing Record 26 of Set 15 | sardarshahr
# Processing Record 27 of Set 15 | westport
# Processing Record 28 of Set 15 | kysyl-syr
# Processing Record 29 of Set 15 | pokhara
# Processing Record 30 of Set 15 | dongsheng
# Processing Record 31 of Set 15 | berlevag
# Processing Record 32 of Set 15 | maragogi
# Processing Record 33 of Set 15 | smyrna
# Processing Record 34 of Set 15 | tikapur
# Processing Record 35 of Set 15 | ammon
# Processing Record 36 of Set 15 | lang son
# Processing Record 37 of Set 15 | verkhovyna
# Processing Record 38 of Set 15 | zhaoqing
# Processing Record 39 of Set 15 | nevers
# Processing Record 40 of Set 15 | cortez
# Processing Record 41 of Set 15 | usakos
# Processing Record 42 of Set 15 | angoche
# Processing Record 43 of Set 15 | lata
# Processing Record 44 of Set 15 | north bend
# Processing Record 45 of Set 15 | belogorsk
# Processing Record 46 of Set 15 | rantepao
# Processing Record 47 of Set 15 | port blair
# Processing Record 48 of Set 15 | lagarto
# Processing Record 49 of Set 15 | nizhniy kuranakh
# Processing Record 50 of Set 15 | tucumcari
# Processing Record 1 of Set 16 | te anau
# Processing Record 2 of Set 16 | zandvoort
# Processing Record 3 of Set 16 | beni
# Processing Record 4 of Set 16 | linxia
# Processing Record 5 of Set 16 | taga dzong
# City not found. Skipping...
# Processing Record 6 of Set 16 | khandbari
# Processing Record 7 of Set 16 | beringovskiy
# Processing Record 8 of Set 16 | brownwood
# Processing Record 9 of Set 16 | omsukchan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Gatton      AU -27.5500  152.2833     53.64        91           0
# 1        Tevaitoa      PF -16.7833 -151.5000     77.52        74          68
# 2    Kruisfontein      ZA -34.0033   24.7314     47.88        78           9
# 3      Bredasdorp      ZA -34.5322   20.0403     51.44        93           2
# 4          Urumqi      CN  43.8010   87.6005     59.95        77          75
# ..            ...     ...      ...       ...       ...       ...         ...
# 694        Linxia      CN  35.6003  103.2064     62.46        42           0
# 695     Khandbari      NP  27.3747   87.2039     73.36        96         100
# 696  Beringovskiy      RU  63.0500  179.3167     42.67        71          99
# 697     Brownwood      US  31.7093  -98.9912    102.29        30          30
# 698     Omsukchan      RU  62.5333  155.8000     41.95        76          93
#
#      Wind Speed       Description
# 0          0.94         clear sky
# 1         17.38     broken clouds
# 2          4.03         clear sky
# 3          4.21         clear sky
# 4          6.71     broken clouds
# ..          ...               ...
# 694        5.37         clear sky
# 695        2.15   overcast clouds
# 696       16.58   overcast clouds
# 697       11.03  scattered clouds
# 698        6.26   overcast clouds
#
# [699 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
